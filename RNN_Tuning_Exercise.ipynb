# %% [markdown]
# <a href="https://colab.research.google.com/github/stevengregori92/RNN-Intro/blob/main/RNN_Tuning_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install 'jcopdl<2.0'
# !pip install gdown
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting jcopdl<2.0
#   Downloading jcopdl-1.1.10.tar.gz (12 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from jcopdl<2.0) (2.0.1+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from jcopdl<2.0) (1.22.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from jcopdl<2.0) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from jcopdl<2.0) (3.7.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from jcopdl<2.0) (8.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->jcopdl<2.0) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->jcopdl<2.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->jcopdl<2.0) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->jcopdl<2.0) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->jcopdl<2.0) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->jcopdl<2.0) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->jcopdl<2.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->jcopdl<2.0) (2022.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->jcopdl<2.0) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->jcopdl<2.0) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->jcopdl<2.0) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->jcopdl<2.0) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->jcopdl<2.0) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->jcopdl<2.0) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->jcopdl<2.0) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->jcopdl<2.0) (16.0.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->jcopdl<2.0) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->jcopdl<2.0) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->jcopdl<2.0) (1.3.0)
# Building wheels for collected packages: jcopdl
#   Building wheel for jcopdl (setup.py) ... done
#   Created wheel for jcopdl: filename=jcopdl-1.1.10-py2.py3-none-any.whl size=17913 sha256=9a750d3ccf8ba6705103fe035de7b6bc0376f86ed850fce251a8a6ff4f60f4e5
#   Stored in directory: /root/.cache/pip/wheels/41/95/30/86345d2446be19c7d97dee789a2597bee81cfbb7b24a847f7c
# Successfully built jcopdl
# Installing collected packages: jcopdl
# Successfully installed jcopdl-1.1.10
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.6.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.12.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.27.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.65.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.4.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
from jcopdl.callback import set_config

# %%
# !gdown https://drive.google.com/uc?id=18y76hccJ6C7CD0uMJ2KjSFGJhYx168sR
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=18y76hccJ6C7CD0uMJ2KjSFGJhYx168sR
# To: /content/utils.py
# 100% 1.71k/1.71k [00:00<00:00, 7.38MB/s]

# %%
# !gdown https://drive.google.com/uc?id=1pi7ras5xdI9Zb3QoS90NO3jsEuYrbQAM
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1pi7ras5xdI9Zb3QoS90NO3jsEuYrbQAM
# To: /content/data.zip
# 100% 95.8k/95.8k [00:00<00:00, 92.7MB/s]

# %%
# !unzip /content/data.zip
# Out:
# Archive:  /content/data.zip
#    creating: data/
#   inflating: data/.DS_Store
#   inflating: data/sine_new.csv
#    creating: data/.ipynb_checkpoints/
#   inflating: data/jkse.csv
#   inflating: data/daily_min_temp.csv
#   inflating: data/sine.csv

# %%
train_set.n_seq
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-bc2911c8c9e5> in <cell line: 1>()
# ----> 1 train_set.n_seq
#
# NameError: name 'train_set' is not defined

# %%
# data = "damped_sine"
data = "jkse"

config = set_config({
    "input_size": 1,
    "seq_len": 5,
    "batch_size": 64,
    "output_size": 1,
    "hidden_size": 128,
    "num_layers": 2,
    "dropout": 0.2,
    "bidirectional": False, # True/False
    "cell_type": "gru" # rnn/gru/lstm
})

lr =0.0005

# %% [markdown]
# # Jangan edit code di bawah ini

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

import torch
from torch import nn, optim
from jcopdl.callback import Callback
from jcopdl.utils.dataloader import TimeSeriesDataset
from torch.utils.data import DataLoader
from utils import data4pred, pred4pred

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device

class RNN(nn.Module):
    def __init__(self, cell_type, input_size, output_size, hidden_size, num_layers, dropout, bidirectional):
        super().__init__()
        
        if cell_type == "rnn":
            rnn_block = nn.RNN
        elif cell_type == "lstm":
            rnn_block = nn.LSTM
        elif cell_type == "gru":
            rnn_block = nn.GRU
        
        self.rnn = rnn_block(input_size, hidden_size, num_layers, dropout=dropout, bidirectional=bidirectional)
        
        if bidirectional:
            hidden_size = 2*hidden_size
            
        self.fc = nn.Linear(hidden_size, output_size)
        
    def forward(self, x, hidden):        
        x, hidden = self.rnn(x, hidden)
        x = self.fc(x)
        return x, hidden
    
if data == "damped_sine":
    df = pd.read_csv("data/sine_new.csv", parse_dates=["Date"], index_col="Date")
    df.value = df.value.transform(lambda x: (x-x.mean())/x.std())
    col = "value"    
elif data == "jkse":
    df = pd.read_csv("data/jkse.csv", parse_dates=["Date"], index_col="Date")
    df = df[~df.price.isna()]
    df.price = df.price.transform(lambda x: (x-x.mean())/x.std())
    col = "price"

ts_train, ts_test = train_test_split(df, test_size=0.2, shuffle=False)

train_set = TimeSeriesDataset(ts_train, col, config.seq_len)
trainloader = DataLoader(train_set, batch_size=config.batch_size)

test_set = TimeSeriesDataset(ts_test, col, config.seq_len)
testloader = DataLoader(test_set, batch_size=config.batch_size)

model = RNN(config.cell_type, config.input_size, config.output_size, config.hidden_size, 
            config.num_layers, config.dropout, config.bidirectional).to(device)
criterion = nn.MSELoss(reduction='mean')
optimizer = optim.AdamW(model.parameters(), lr=lr)
callback = Callback(model, config, outdir=f'model/{data}/')

from tqdm.auto import tqdm

def loop_fn(mode, dataset, dataloader, model, criterion, optimizer, device):
    if mode == "train":
        model.train()
    elif mode == "test":
        model.eval()
    cost = 0
    for feature, target in tqdm(dataloader, desc=mode.title()):
        feature, target = feature.to(device), target.to(device)
        output, hidden = model(feature, None)
        loss = criterion(output, target)
        
        if mode == "train":
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        
        cost += loss.item() * feature.shape[0]
    cost = cost / len(dataset)
    return cost

while True:
    train_cost = loop_fn("train", train_set, trainloader, model, criterion, optimizer, device)
    with torch.no_grad():
        test_cost = loop_fn("test", test_set, testloader, model, criterion, optimizer, device)
    
    # Logging
    callback.log(train_cost, test_cost)

    # Checkpoint
    callback.save_checkpoint()
        
    # Runtime Plotting
    callback.cost_runtime_plotting()
    
    # Early Stopping
    if callback.early_stopping(model, monitor="test_cost"):
        callback.plot_cost()
        break
        
# Forecast
train_forecast_set = TimeSeriesDataset(ts_train, col, 1)
trainforecastloader = DataLoader(train_forecast_set)

test_forecast_set = TimeSeriesDataset(ts_test, col, 1)
testforecastloader = DataLoader(test_forecast_set)

plt.figure(figsize=(15, 15))
    
plt.subplot(311)
data4pred(model, train_forecast_set, trainforecastloader, device)
plt.title("Train")

plt.subplot(312)
data4pred(model, test_forecast_set, testforecastloader, device)
plt.title("Test")

plt.subplot(313)
pred4pred(model, test_forecast_set, testforecastloader, device, n_prior=400, n_forecast=100)
plt.title("Test");
# Out:
# (N, S, F): (323, 6, 1)
# Note: last 1 data excluded
#
# (N, S, F): (80, 6, 1)
# Note: last 5 data excluded
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch     1
# Train_cost  = 0.8396 | Test_cost  = 1.5985 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch     2
# Train_cost  = 0.6663 | Test_cost  = 1.3852 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch     3
# Train_cost  = 0.5445 | Test_cost  = 1.1228 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch     4
# Train_cost  = 0.4160 | Test_cost  = 0.7992 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch     5
# Train_cost  = 0.2727 | Test_cost  = 0.4282 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch     6
# Train_cost  = 0.1369 | Test_cost  = 0.1356 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch     7
# Train_cost  = 0.0895 | Test_cost  = 0.0786 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch     8
# Train_cost  = 0.0932 | Test_cost  = 0.0717 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch     9
# Train_cost  = 0.0825 | Test_cost  = 0.0696 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    10
# Train_cost  = 0.0725 | Test_cost  = 0.0722 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0696
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    11
# Train_cost  = 0.0633 | Test_cost  = 0.0715 |
# ==> EarlyStop patience =  2 | Best test_cost: 0.0696
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    12
# Train_cost  = 0.0610 | Test_cost  = 0.0689 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    13
# Train_cost  = 0.0580 | Test_cost  = 0.0644 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    14
# Train_cost  = 0.0551 | Test_cost  = 0.0585 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    15
# Train_cost  = 0.0531 | Test_cost  = 0.0542 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    16
# Train_cost  = 0.0513 | Test_cost  = 0.0518 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    17
# Train_cost  = 0.0490 | Test_cost  = 0.0503 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    18
# Train_cost  = 0.0468 | Test_cost  = 0.0480 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    19
# Train_cost  = 0.0434 | Test_cost  = 0.0458 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    20
# Train_cost  = 0.0416 | Test_cost  = 0.0428 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    21
# Train_cost  = 0.0404 | Test_cost  = 0.0398 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    22
# Train_cost  = 0.0396 | Test_cost  = 0.0376 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    23
# Train_cost  = 0.0372 | Test_cost  = 0.0359 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    24
# Train_cost  = 0.0359 | Test_cost  = 0.0339 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    25
# Train_cost  = 0.0341 | Test_cost  = 0.0327 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    26
# Train_cost  = 0.0326 | Test_cost  = 0.0314 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    27
# Train_cost  = 0.0310 | Test_cost  = 0.0295 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    28
# Train_cost  = 0.0313 | Test_cost  = 0.0283 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    29
# Train_cost  = 0.0302 | Test_cost  = 0.0285 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0283
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    30
# Train_cost  = 0.0292 | Test_cost  = 0.0260 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    31
# Train_cost  = 0.0285 | Test_cost  = 0.0271 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0260
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    32
# Train_cost  = 0.0275 | Test_cost  = 0.0263 |
# ==> EarlyStop patience =  2 | Best test_cost: 0.0260
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    33
# Train_cost  = 0.0271 | Test_cost  = 0.0243 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    34
# Train_cost  = 0.0257 | Test_cost  = 0.0246 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0243
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    35
# Train_cost  = 0.0253 | Test_cost  = 0.0230 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    36
# Train_cost  = 0.0249 | Test_cost  = 0.0233 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0230
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    37
# Train_cost  = 0.0249 | Test_cost  = 0.0230 |
# ==> EarlyStop patience =  2 | Best test_cost: 0.0230
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    38
# Train_cost  = 0.0242 | Test_cost  = 0.0220 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    39
# Train_cost  = 0.0232 | Test_cost  = 0.0215 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    40
# Train_cost  = 0.0220 | Test_cost  = 0.0211 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    41
# Train_cost  = 0.0218 | Test_cost  = 0.0205 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    42
# Train_cost  = 0.0218 | Test_cost  = 0.0209 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0205
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    43
# Train_cost  = 0.0215 | Test_cost  = 0.0185 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    44
# Train_cost  = 0.0203 | Test_cost  = 0.0196 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0185
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    45
# Train_cost  = 0.0203 | Test_cost  = 0.0188 |
# ==> EarlyStop patience =  2 | Best test_cost: 0.0185
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    46
# Train_cost  = 0.0193 | Test_cost  = 0.0175 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    47
# Train_cost  = 0.0198 | Test_cost  = 0.0190 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0175
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    48
# Train_cost  = 0.0194 | Test_cost  = 0.0158 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    49
# Train_cost  = 0.0185 | Test_cost  = 0.0171 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0158
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    50
# Train_cost  = 0.0178 | Test_cost  = 0.0157 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    51
# Train_cost  = 0.0170 | Test_cost  = 0.0165 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0157
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    52
# Train_cost  = 0.0172 | Test_cost  = 0.0157 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    53
# Train_cost  = 0.0165 | Test_cost  = 0.0151 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    54
# Train_cost  = 0.0158 | Test_cost  = 0.0156 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0151
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    55
# Train_cost  = 0.0159 | Test_cost  = 0.0151 |
# ==> EarlyStop patience =  2 | Best test_cost: 0.0151
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    56
# Train_cost  = 0.0153 | Test_cost  = 0.0142 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    57
# Train_cost  = 0.0149 | Test_cost  = 0.0155 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0142
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    58
# Train_cost  = 0.0152 | Test_cost  = 0.0127 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    59
# Train_cost  = 0.0146 | Test_cost  = 0.0146 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0127
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    60
# Train_cost  = 0.0144 | Test_cost  = 0.0134 |
# ==> EarlyStop patience =  2 | Best test_cost: 0.0127
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    61
# Train_cost  = 0.0140 | Test_cost  = 0.0121 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    62
# Train_cost  = 0.0133 | Test_cost  = 0.0142 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0121
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    63
# Train_cost  = 0.0132 | Test_cost  = 0.0129 |
# ==> EarlyStop patience =  2 | Best test_cost: 0.0121
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    64
# Train_cost  = 0.0124 | Test_cost  = 0.0116 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    65
# Train_cost  = 0.0129 | Test_cost  = 0.0135 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0116
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    66
# Train_cost  = 0.0127 | Test_cost  = 0.0103 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    67
# Train_cost  = 0.0124 | Test_cost  = 0.0136 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0103
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    68
# Train_cost  = 0.0118 | Test_cost  = 0.0111 |
# ==> EarlyStop patience =  2 | Best test_cost: 0.0103
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    69
# Train_cost  = 0.0114 | Test_cost  = 0.0118 |
# ==> EarlyStop patience =  3 | Best test_cost: 0.0103
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    70
# Train_cost  = 0.0108 | Test_cost  = 0.0101 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    71
# Train_cost  = 0.0103 | Test_cost  = 0.0103 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0101
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    72
# Train_cost  = 0.0111 | Test_cost  = 0.0096 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    73
# Train_cost  = 0.0106 | Test_cost  = 0.0111 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0096
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    74
# Train_cost  = 0.0100 | Test_cost  = 0.0089 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    75
# Train_cost  = 0.0097 | Test_cost  = 0.0084 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    76
# Train_cost  = 0.0096 | Test_cost  = 0.0101 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0084
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    77
# Train_cost  = 0.0094 | Test_cost  = 0.0079 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    78
# Train_cost  = 0.0100 | Test_cost  = 0.0102 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0079
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    79
# Train_cost  = 0.0097 | Test_cost  = 0.0075 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    80
# Train_cost  = 0.0098 | Test_cost  = 0.0096 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0075
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    81
# Train_cost  = 0.0089 | Test_cost  = 0.0073 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    82
# Train_cost  = 0.0087 | Test_cost  = 0.0074 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0073
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    83
# Train_cost  = 0.0082 | Test_cost  = 0.0081 |
# ==> EarlyStop patience =  2 | Best test_cost: 0.0073
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    84
# Train_cost  = 0.0082 | Test_cost  = 0.0071 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    85
# Train_cost  = 0.0081 | Test_cost  = 0.0081 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0071
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    86
# Train_cost  = 0.0082 | Test_cost  = 0.0071 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    87
# Train_cost  = 0.0074 | Test_cost  = 0.0070 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    88
# Train_cost  = 0.0073 | Test_cost  = 0.0068 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    89
# Train_cost  = 0.0079 | Test_cost  = 0.0055 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    90
# Train_cost  = 0.0073 | Test_cost  = 0.0085 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0055
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    91
# Train_cost  = 0.0077 | Test_cost  = 0.0060 |
# ==> EarlyStop patience =  2 | Best test_cost: 0.0055
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    92
# Train_cost  = 0.0073 | Test_cost  = 0.0065 |
# ==> EarlyStop patience =  3 | Best test_cost: 0.0055
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    93
# Train_cost  = 0.0072 | Test_cost  = 0.0052 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    94
# Train_cost  = 0.0067 | Test_cost  = 0.0055 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0052
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    95
# Train_cost  = 0.0065 | Test_cost  = 0.0056 |
# ==> EarlyStop patience =  2 | Best test_cost: 0.0052
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    96
# Train_cost  = 0.0062 | Test_cost  = 0.0057 |
# ==> EarlyStop patience =  3 | Best test_cost: 0.0052
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    97
# Train_cost  = 0.0059 | Test_cost  = 0.0047 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    98
# Train_cost  = 0.0063 | Test_cost  = 0.0065 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0047
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch    99
# Train_cost  = 0.0068 | Test_cost  = 0.0043 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   100
# Train_cost  = 0.0074 | Test_cost  = 0.0086 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0043
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   101
# Train_cost  = 0.0084 | Test_cost  = 0.0043 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   102
# Train_cost  = 0.0078 | Test_cost  = 0.0069 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0043
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   103
# Train_cost  = 0.0071 | Test_cost  = 0.0044 |
# ==> EarlyStop patience =  2 | Best test_cost: 0.0043
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   104
# Train_cost  = 0.0055 | Test_cost  = 0.0045 |
# ==> EarlyStop patience =  3 | Best test_cost: 0.0043
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   105
# Train_cost  = 0.0055 | Test_cost  = 0.0047 |
# ==> EarlyStop patience =  4 | Best test_cost: 0.0043
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   106
# Train_cost  = 0.0053 | Test_cost  = 0.0040 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   107
# Train_cost  = 0.0056 | Test_cost  = 0.0055 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0040
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   108
# Train_cost  = 0.0051 | Test_cost  = 0.0039 |
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   109
# Train_cost  = 0.0051 | Test_cost  = 0.0045 |
# ==> EarlyStop patience =  1 | Best test_cost: 0.0039
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   110
# Train_cost  = 0.0048 | Test_cost  = 0.0042 |
# ==> EarlyStop patience =  2 | Best test_cost: 0.0039
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   111
# Train_cost  = 0.0046 | Test_cost  = 0.0040 |
# ==> EarlyStop patience =  3 | Best test_cost: 0.0039
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   112
# Train_cost  = 0.0047 | Test_cost  = 0.0050 |
# ==> EarlyStop patience =  4 | Best test_cost: 0.0039
# Train:   0%|          | 0/6 [00:00<?, ?it/s]
# Test:   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch   113
# Train_cost  = 0.0048 | Test_cost  = 0.0040 |
# ==> EarlyStop patience =  5 | Best test_cost: 0.0039
# ==> Execute Early Stopping at epoch: 113 | Best test_cost: 0.0039
# ==> Best model is saved at model/jkse/
# (N, S, F): (1939, 1, 1)
# Note: last 0 data excluded
#
# (N, S, F): (485, 1, 1)
# Note: last 0 data excluded
